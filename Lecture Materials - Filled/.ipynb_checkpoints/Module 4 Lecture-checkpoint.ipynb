# %% [markdown]
# # Module 4 Lecture - Loading and Exploring Data

# %% [markdown]
# Import packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading in data - using ISISTweetsenhanced.csv

# %%
df=pd.read_csv(r'C:\Users\mwbarr\Python for Data Analysis\Data Files\isistweetsenhanced.csv')
pd.read_csv(r'C:\Users\mwbarr\Python for Data Analysis\Data Files\isistweetsenhanced.csv',encoding='utf-8')
pd.read_csv(r'C:\Users\mwbarr\Python for Data Analysis\Data Files\isistweetsenhanced.csv',encoding='ISO-8859-1')
# Out:
#        Unnamed: 0                     name         username  \
# 0               0            GunsandCoffee  GunsandCoffee70
# 1               1            GunsandCoffee  GunsandCoffee70
# 2               2            GunsandCoffee  GunsandCoffee70
# 3               3            GunsandCoffee  GunsandCoffee70
# 4               4            GunsandCoffee  GunsandCoffee70
# 5               5            GunsandCoffee  GunsandCoffee70
# 6               6            GunsandCoffee  GunsandCoffee70
# 7               7            GunsandCoffee  GunsandCoffee70
# 8               8            GunsandCoffee  GunsandCoffee70
# 9               9            GunsandCoffee  GunsandCoffee70
# 10             10            GunsandCoffee  GunsandCoffee70
# 11             11            GunsandCoffee  GunsandCoffee70
# 12             12            GunsandCoffee  GunsandCoffee70
# 13             13            GunsandCoffee  GunsandCoffee70
# 14             14            GunsandCoffee  GunsandCoffee70
# ...

# %% [markdown]
# Reading in sampleJson.txt

# %%
import pandas as pd
import json
file=open(r'C:\Users\mwbarr\Python for Data Analysis\Data Files\sampleJson.txt','r')
sampleJson=json.load(file)
sampleJson
# Out:
# {'colors': [{'category': 'hue',
#    'code': {'hex': '#000', 'rgba': [255, 255, 255, 1]},
#    'color': 'black',
#    'type': 'primary'},
#   {'category': 'value',
#    'code': {'hex': '#FFF', 'rgba': [0, 0, 0, 1]},
#    'color': 'white'}]}

# %%
pd.io.json.json_normalize(sampleJson['colors'],record_path=[['code','rgba']], meta=['category','color'])
# Out:
#      0 category  color
# 0  255      hue  black
# 1  255      hue  black
# 2  255      hue  black
# 3    1      hue  black
# 4    0    value  white
# 5    0    value  white
# 6    0    value  white
# 7    1    value  white

# %% [markdown]
# From a dictionary

# %%
fruits=pd.DataFrame({'Name':['Apple','Orange'],'Price':[2,3]})
fruits
# Out:
#      Name  Price
# 0   Apple      2
# 1  Orange      3

# %% [markdown]
# Selecting row(s) and column(s)

# %%
df['username']
# Out:
# 0        GunsandCoffee70
# 1        GunsandCoffee70
# 2        GunsandCoffee70
# 3        GunsandCoffee70
# 4        GunsandCoffee70
# 5        GunsandCoffee70
# 6        GunsandCoffee70
# 7        GunsandCoffee70
# 8        GunsandCoffee70
# 9        GunsandCoffee70
# 10       GunsandCoffee70
# 11       GunsandCoffee70
# 12       GunsandCoffee70
# 13       GunsandCoffee70
# 14       GunsandCoffee70
# 15       GunsandCoffee70
# 16       GunsandCoffee70
# 17       GunsandCoffee70
# 18       GunsandCoffee70
# 19       GunsandCoffee70
# 20       GunsandCoffee70
# 21       GunsandCoffee70
# 22       GunsandCoffee70
# 23       GunsandCoffee70
# 24       GunsandCoffee70
# 25       GunsandCoffee70
# 26       GunsandCoffee70
# 27       GunsandCoffee70
# 28       GunsandCoffee70
# 29       AbuLaythAlHindi
#               ...
# 17380         melvynlion
# 17381        Nidalgazaui
# 17382            nvor85j
# 17383        Nidalgazaui
# 17384     Mountainjjoool
# 17385            nvor85j
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                        0
# name                                                  GunsandCoffee
# username                                            GunsandCoffee70
# description            ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews
# location                                                        NaN
# followers                                                       640
# numberstatuses                                                   49
# time                                                 1/6/2015 21:07
# tweets            ENGLISH TRANSLATION: 'A MESSAGE TO THE TRUTHFU...
# Hashtag 0                                                       NaN
# Hashtag 1                                                       NaN
# Hashtag 2                                                       NaN
# Hashtag 3                                                       NaN
# Hashtag 4                                                       NaN
# ...

# %% [markdown]
# Adding rows

# %%
fruits=fruits.append({'Name':'Banana','Price':3},ignore_index=True)
fruits
# Out:
#      Name  Price
# 0   Apple      2
# 1  Orange      3
# 2  Banana      3
# 3  Banana      3

# %% [markdown]
# Adding Columns

# %%
fruits['Color']=['Red','Orange','Banana','Yellow']
fruits
# Out:
#      Name  Price   Color
# 0   Apple      2     Red
# 1  Orange      3  Orange
# 2  Banana      3  Banana
# 3  Banana      3  Yellow

# %% [markdown]
# Renaming Columns

# %%
df=df.rename(columns={'Unnamed: 0':'Example'})
df
# Out:
#        Example                name         username  \
# 0            0       GunsandCoffee  GunsandCoffee70
# 1            1       GunsandCoffee  GunsandCoffee70
# 2            2       GunsandCoffee  GunsandCoffee70
# 3            3       GunsandCoffee  GunsandCoffee70
# 4            4       GunsandCoffee  GunsandCoffee70
# 5            5       GunsandCoffee  GunsandCoffee70
# 6            6       GunsandCoffee  GunsandCoffee70
# 7            7       GunsandCoffee  GunsandCoffee70
# 8            8       GunsandCoffee  GunsandCoffee70
# 9            9       GunsandCoffee  GunsandCoffee70
# 10          10       GunsandCoffee  GunsandCoffee70
# 11          11       GunsandCoffee  GunsandCoffee70
# 12          12       GunsandCoffee  GunsandCoffee70
# 13          13       GunsandCoffee  GunsandCoffee70
# 14          14       GunsandCoffee  GunsandCoffee70
# 15          15       GunsandCoffee  GunsandCoffee70
# 16          16       GunsandCoffee  GunsandCoffee70
# ...

# %% [markdown]
# Pandas functions - functions that summarize, functions that transform (not in place)

# %%
df.shape
# Out:
# (17410, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17410 entries, 0 to 17409
# Data columns (total 16 columns):
# Example           17410 non-null int64
# name              17410 non-null object
# username          17410 non-null object
# description       14728 non-null object
# location          11432 non-null object
# followers         17410 non-null int64
# numberstatuses    17410 non-null int64
# time              17410 non-null object
# tweets            17410 non-null object
# Hashtag 0         7136 non-null object
# Hashtag 1         4864 non-null object
# Hashtag 2         2900 non-null object
# Hashtag 3         1436 non-null object
# Hashtag 4         602 non-null object
# Hashtag 5         252 non-null object
# Hashtag 6         101 non-null object
# dtypes: int64(3), object(13)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#             Example     followers  numberstatuses
# count  17410.000000  17410.000000    17410.000000
# mean    8704.500000   3975.076680     4760.787651
# std     5025.978429   8674.378495     7015.967275
# min        0.000000     16.000000        1.000000
# 25%     4352.250000    266.000000      207.000000
# 50%     8704.500000    928.000000      908.000000
# 75%    13056.750000   1791.000000     6865.000000
# max    17409.000000  34692.000000    33091.000000

# %% [markdown]
# Getting summary statistics on whole dataframe and individual columns

# %%
df['followers'].mean()
# Out:
# 3975.0766800689257

# %%
df['username'].value_counts()
# Out:
# Uncle_SamCoco                                                                                                                                                                                                                                                                                                       1580
# RamiAlLolah                                                                                                                                                                                                                                                                                                         1475
# warrnews                                                                                                                                                                                                                                                                                                            1191
# ...

# %%
df.columns
# Out:
# Index(['Example', 'name', 'username', 'description', 'location', 'followers',
#        'numberstatuses', 'time', 'tweets', 'Hashtag 0', 'Hashtag 1',
#        'Hashtag 2', 'Hashtag 3', 'Hashtag 4', 'Hashtag 5', 'Hashtag 6'],
#       dtype='object')

# %%
df.head()
# Out:
#    Example           name         username  \
# 0        0  GunsandCoffee  GunsandCoffee70
# 1        1  GunsandCoffee  GunsandCoffee70
# 2        2  GunsandCoffee  GunsandCoffee70
# 3        3  GunsandCoffee  GunsandCoffee70
# 4        4  GunsandCoffee  GunsandCoffee70
#
#                                     description location  followers  \
# 0  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 1  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 2  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 3  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 4  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
#
#    numberstatuses            time  \
# 0              49  1/6/2015 21:07
# 1              49  1/6/2015 21:27
# 2              49  1/6/2015 21:29
# 3              49  1/6/2015 21:37
# 4              49  1/6/2015 21:45
#
#                                               tweets Hashtag 0 Hashtag 1  \
# ...

# %% [markdown]
# Making basic plots

# %%
# %matplotlib inline
df['followers'].plot.hist()
df.plot.scatter(x='followers',y='numberstatuses')

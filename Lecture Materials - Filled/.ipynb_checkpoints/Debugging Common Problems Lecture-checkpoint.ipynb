# %% [markdown]
# # Module 11 - Debugging Problems

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\mwbarr\Python for Data Analysis\Data Files\isistweetsenhanced.csv')
df['followers']=df['followers'].astype(str)

# %% [markdown]
# Syntax Errors - Various Kinds

# %%
a='b'
# Out:
#   File "<ipython-input-5-3a0a001c7163>", line 1
#     a='b
#         ^
# SyntaxError: EOL while scanning string literal

# %%
print('gfbfg')
# Out:
# gfbfg

# %%
for i in [1,2,3,4]:
    print(i)
# Out:
#   File "<ipython-input-8-589b792e71c4>", line 2
#     print(i)
#         ^
# IndentationError: expected an indented block

# %%
for i in [1,2,3,4]:
    print(i)
    print(i)
# Out:
#   File "<ipython-input-9-cfd9ffacd7ed>", line 3
#     print(i)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Key Errors

# %%
df['Username']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Username'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-2c2a520fcb77> in <module>()
# ----> 1 df['Username']
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Username'

# %% [markdown]
# Missing Variable Errors

# %%
DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-33c4439a987d> in <module>()
# ----> 1 DF
#
# NameError: name 'DF' is not defined

# %% [markdown]
# Data Type Errors

# %%
df['username'].std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     118                 else:
# --> 119                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     120             except Exception:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof)
#     417     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# --> 418     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#     419     if axis is not None:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# ValueError: could not convert string to float: 'GunsandCoffee70'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     121                 try:
# --> 122                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     123                 except ValueError as e:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof)
#     417     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# --> 418     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#     419     if axis is not None:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# ValueError: could not convert string to float: 'GunsandCoffee70'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     118                 else:
# --> 119                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     120             except Exception:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanstd(values, axis, skipna, ddof)
#     387 def nanstd(values, axis=None, skipna=True, ddof=1):
# --> 388     result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof))
#     389     return _wrap_results(result, values.dtype)
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     129                     if is_object_dtype(values):
# --> 130                         raise TypeError(e)
#     131                     raise
#
# TypeError: could not convert string to float: 'GunsandCoffee70'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     118                 else:
# --> 119                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     120             except Exception:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof)
#     417     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# --> 418     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#     419     if axis is not None:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# ValueError: could not convert string to float: 'GunsandCoffee70'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     121                 try:
# --> 122                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     123                 except ValueError as e:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof)
#     417     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# --> 418     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#     419     if axis is not None:
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# ValueError: could not convert string to float: 'GunsandCoffee70'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3f7244ea6fd7> in <module>()
# ----> 1 df['username'].std()
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#    6215                                       skipna=skipna, ddof=ddof)
#    6216         return self._reduce(f, name, axis=axis, numeric_only=numeric_only,
# -> 6217                             skipna=skipna, ddof=ddof)
#    6218
#    6219     return set_function_name(stat_func, name, cls)
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2379                                           'numeric_only.'.format(name))
#    2380             with np.errstate(all='ignore'):
# -> 2381                 return op(delegate, skipna=skipna, **kwds)
#    2382
#    2383         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     120             except Exception:
#     121                 try:
# --> 122                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     123                 except ValueError as e:
#     124                     # we want to transform an object array
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanstd(values, axis, skipna, ddof)
#     386 @bottleneck_switch(ddof=1)
#     387 def nanstd(values, axis=None, skipna=True, ddof=1):
# --> 388     result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof))
#     389     return _wrap_results(result, values.dtype)
#     390
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# C:\Users\mwbarr\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     128
#     129                     if is_object_dtype(values):
# --> 130                         raise TypeError(e)
#     131                     raise
#     132
#
# TypeError: could not convert string to float: 'GunsandCoffee70'

# %% [markdown]
# Reading and diagnosing more complex errors and bugs

# %%
def aggFunc(s):
        s=s*2
        s=s+1
        return s.sum()
df.groupby('location').agg({'followers':aggFunc})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in masked_arith_op(x, y, op)
#    1025             with np.errstate(all='ignore'):
# -> 1026                 result[mask] = op(xrav[mask], y)
#    1027
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     855         if len(output) == 0:
# --> 856             return self._python_apply_general(f)
#     857
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-57-b4b9612dd329> in aggFunc(s)
#       2         s=s*2
# ----> 3         s=s+1
#       4         return s.sum()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in masked_arith_op(x, y, op)
#    1025             with np.errstate(all='ignore'):
# -> 1026                 result[mask] = op(xrav[mask], y)
#    1027
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-b4b9612dd329> in <module>
#       3         s=s+1
#       4         return s.sum()
# ----> 5 df.groupby('location').agg({'followers':aggFunc})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     496
#     497                 try:
# --> 498                     result = _agg(arg, _agg_1dim)
#     499                 except SpecificationError:
#     500
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#     431                                              "in aggregation")
# --> 432                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     433
#     434             def _agg_2dim(name, how):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     905         for name, group in self:
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#     909                 raise Exception('Must produce aggregated value')
#
# <ipython-input-57-b4b9612dd329> in aggFunc(s)
#       1 def aggFunc(s):
#       2         s=s*2
# ----> 3         s=s+1
#       4         return s.sum()
#       5 df.groupby('location').agg({'followers':aggFunc})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1581             rvalues = rvalues.values
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#    1585                                 index=left.index, name=res_name, dtype=None)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Print involved variables immediately before error

# %%
def aggFunc(s):
        s=s*2
        print(s)
        s=s+1
        return s.sum()
df.groupby('location').agg({'followers':aggFunc})
# Out:
# 1389    1919
# 1392    1919
# 1414    1919
# 3690    3030
# Name: followers, dtype: object
# 1389    1919
# 1392    1919
# 1414    1919
# 3690    3030
# Name: followers, dtype: object
# 1389    1919
# 1392    1919
# 1414    1919
# 3690    3030
# Name: ., dtype: object
# 1389    1919
# 1392    1919
# 1414    1919
# 3690    3030
# Name: ., dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in masked_arith_op(x, y, op)
#    1025             with np.errstate(all='ignore'):
# -> 1026                 result[mask] = op(xrav[mask], y)
#    1027
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     855         if len(output) == 0:
# --> 856             return self._python_apply_general(f)
#     857
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-59-1802efc50931> in aggFunc(s)
#       3         print(s)
# ----> 4         s=s+1
#       5         return s.sum()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in masked_arith_op(x, y, op)
#    1025             with np.errstate(all='ignore'):
# -> 1026                 result[mask] = op(xrav[mask], y)
#    1027
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-1802efc50931> in <module>
#       4         s=s+1
#       5         return s.sum()
# ----> 6 df.groupby('location').agg({'followers':aggFunc})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     496
#     497                 try:
# --> 498                     result = _agg(arg, _agg_1dim)
#     499                 except SpecificationError:
#     500
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#     431                                              "in aggregation")
# --> 432                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     433
#     434             def _agg_2dim(name, how):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     905         for name, group in self:
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#     909                 raise Exception('Must produce aggregated value')
#
# <ipython-input-59-1802efc50931> in aggFunc(s)
#       2         s=s*2
#       3         print(s)
# ----> 4         s=s+1
#       5         return s.sum()
#       6 df.groupby('location').agg({'followers':aggFunc})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1581             rvalues = rvalues.values
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#    1585                                 index=left.index, name=res_name, dtype=None)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Between the dtype object here and the error message, you've probably figured out that these numbers aren't properly coded as numbers. We can change the data type easily enough.  Before we do, and so that we can fix it properly, let's figure out the other bug - that's not throwing an error (the multiplication).

# %% [markdown]
# Printing before and after a confusing line to figure out what's going on

# %%
def aggFunc(s):
        print('Before',s)
        s=s*2
        print('After',s)
        s=s+1
        return s.sum()
df['followers']=df['followers'].astype(int)
df.groupby('location').agg({'followers':aggFunc})
# Out:
# Before 1389    19
# 1392    19
# 1414    19
# 3690    30
# Name: followers, dtype: int32
# After 1389    38
# 1392    38
# 1414    38
# 3690    60
# Name: followers, dtype: int32
# Before 2777    276
# 2778    276
# 2820    276
# 2821    276
# 2823    276
# 2824    276
# 2835    276
# 2836    276
# 2837    276
# 2838    276
# 2839    276
# 2840    276
# 2841    276
# 2842    276
# 2843    276
# 2844    276
# 2845    276
# 2846    276
# 2849    276
# 2850    276
# 2851    276
# 2852    276
# 2893    276
# 2894    276
# 2895    276
# 2897    276
# 2907    276
# 2908    276
# 2910    276
# 2913    276
#        ...
# 7104    379
# 7455    379
# 7498    379
# 7499    379
# 7567    379
# 7616    379
# 7618    379
# 7619    379
# 7620    379
# 7621    379
# 7622    379
# 7636    379
# 7835    430
# 7837    430
# 7868    430
# 8175    430
# 8209    430
# 8250    430
# 8251    430
# 8255    430
# 8371    430
# 8403    430
# 8404    430
# 8405    430
# 8553    430
# 8554    430
# 8555    430
# 8556    430
# 8557    430
# 8558    430
# Name: followers, Length: 426, dtype: int32
# After 2777    552
# 2778    552
# 2820    552
# 2821    552
# 2823    552
# 2824    552
# 2835    552
# 2836    552
# 2837    552
# 2838    552
# 2839    552
# 2840    552
# 2841    552
# 2842    552
# 2843    552
# 2844    552
# 2845    552
# 2846    552
# 2849    552
# 2850    552
# 2851    552
# 2852    552
# 2893    552
# 2894    552
# 2895    552
# 2897    552
# 2907    552
# 2908    552
# 2910    552
# 2913    552
#        ...
# 7104    758
# 7455    758
# 7498    758
# 7499    758
# 7567    758
# 7616    758
# 7618    758
# 7619    758
# 7620    758
# 7621    758
# 7622    758
# 7636    758
# 7835    860
# 7837    860
# 7868    860
# 8175    860
# 8209    860
# 8250    860
# 8251    860
# 8255    860
# 8371    860
# 8403    860
# 8404    860
# 8405    860
# 8553    860
# 8554    860
# 8555    860
# 8556    860
# 8557    860
# 8558    860
# Name: followers, Length: 426, dtype: int32
# Before 8223    131
# 8224    131
# 8230    131
# 8235    131
# 8237    131
# 8238    131
# 8239    131
# 8240    131
# 8242    131
# 8243    131
# 8244    131
# 8245    131
# 8246    131
# 8247    131
# 8248    131
# 8249    131
# 8273    131
# 8274    131
# 8277    131
# 8278    131
# 8279    131
# 8280    131
# 8281    131
# Name: followers, dtype: int32
# After 8223    262
# 8224    262
# 8230    262
# 8235    262
# 8237    262
# 8238    262
# 8239    262
# 8240    262
# 8242    262
# 8243    262
# 8244    262
# 8245    262
# 8246    262
# 8247    262
# 8248    262
# 8249    262
# 8273    262
# 8274    262
# 8277    262
# 8278    262
# 8279    262
# 8280    262
# 2346    3186
# 2354    3186
# 2403    3186
# 2404    3186
# 2413    3186
# 2415    3186
# 2418    3186
# 2428    3186
# 2432    3186
# 2486    3186
# 2505    3186
# 2509    3186
# 2510    3186
# 2524    3186
# 2527    3186
# 2538    3186
# 2540    3186
# 2544    3186
# 2545    3186
# 2547    3186
# 2567    3186
# 2568    3186
# 2569    3186
# 2570    3186
# 2572    3186
# 2574    3186
# 2581    3186
# 2582    3186
# 2588    3186
# Name: followers, Length: 99, dtype: int32
# Before 13975     79
# 13977     79
# 13978     79
# 13980     79
# 13981     79
# 13991     79
# 13996     79
# 13997     79
# 14012     79
# 14013     79
# 14014     79
# 14036     79
# 14037     79
# 14123     79
# 14124     79
# 14150     79
# 14152     79
# 14153     79
# 14156     79
# 14158     79
# 14160     79
# 14161     79
# 14176     79
# 14177     79
# 14178     79
# 14269     79
# 14270     79
# 14271     79
# 14274     79
# 14285     79
#         ...
# 16611    270
# 16616    270
# 16637    270
# 16640    270
# 16642    270
# 16645    270
# 16647    270
# 16654    270
# 16655    270
# 16657    270
# 16658    270
# 16677    270
# 16679    270
# 16750    270
# 16752    270
# 16849    270
# 16877    270
# 16880    270
# 16882    270
# 16883    270
# 16896    270
# 17085    270
# 17089    270
# 17090    270
# 17102    270
# 17114    270
# 17250    270
# 17262    270
# 17267    270
# 17282    270
# Name: followers, Length: 182, dtype: int32
# After 13975    158
# 13977    158
# 13978    158
# 13980    158
# 13981    158
# 13991    158
# 13996    158
# 13997    158
# 14012    158
# 14013    158
# 14014    158
# 14036    158
# 14037    158
# 14123    158
# 14124    158
# 14150    158
# 14152    158
# 14153    158
# 14156    158
# 14158    158
# 14160    158
# 14161    158
# 14176    158
# 14177    158
# 14178    158
# 14269    158
# 14270    158
# 14271    158
# 14274    158
# 14285    158
#         ...
# 16611    540
# 16616    540
# 16637    540
# 16640    540
# 16642    540
# 16645    540
# 16647    540
# 16654    540
# 16655    540
# 16657    540
# 16658    540
# 16677    540
# 16679    540
# 16750    540
# 16752    540
# 16849    540
# 16877    540
# 16880    540
# 16882    540
# 16883    540
# 16896    540
# 17085    540
# 17089    540
# 17090    540
# 17102    540
# 17114    540
# 17250    540
# 17262    540
# 17267    540
# 17282    540
# Name: followers, Length: 182, dtype: int32
# Before 5775    56
# 5776    56
# 5822    56
# 5832    56
# 5833    56
# 5834    56
# 5857    56
# 5858    56
# 5859    56
# 5860    56
# 5861    56
# 5863    56
# 5864    56
# 5865    56
# Name: followers, dtype: int32
# After 5775    112
# 5776    112
# 5822    112
# 5832    112
# 5833    112
# 5834    112
# 5857    112
# 5858    112
# 5859    112
# 5860    112
# 5861    112
# 5863    112
# 5864    112
# 5865    112
# Name: followers, dtype: int32
# Before 3981    44
# 3989    44
# 3995    44
# 4000    44
# 4011    44
# 4017    44
# 4022    44
# 4026    44
# 4035    44
# 4036    44
# 4038    44
# 4040    44
# 4041    44
# 4042    44
# 4045    44
# 4046    44
# 4049    44
# 4069    44
# 4073    44
# 9851    148
# Name: followers, Length: 96, dtype: int32
# Before 1437    57
# 1438    57
# 1441    57
# 1442    57
# 1443    57
# 1446    57
# 1449    57
# 1453    57
# 1475    57
# 1563    57
# 1925    57
# 1926    57
# 1927    57
# 1928    57
# 2373    57
# 2725    57
# 2753    57
# 2756    57
# 3115    57
# 3164    57
# 3697    73
# 4001    73
# 4269    73
# 5573    99
# 5574    99
# 5971    99
# 7042    97
# Name: followers, dtype: int32
# After 1437    114
# 1438    114
# 1441    114
# 1442    114
# 1443    114
# 1446    114
# 1449    114
# 1453    114
# 1475    114
# 1563    114
# 1925    114
# 1926    114
# 1927    114
# 1928    114
# 2373    114
# 2725    114
# 2753    114
# 2756    114
# 3115    114
# 3164    114
# 3697    146
# 4001    146
# 4269    146
# 5573    198
# 5574    198
# 5971    198
# 7042    194
# Name: followers, dtype: int32
# Before 5962     447
# 5963     447
# 5964     447
# 5965     447
# 5966     447
# 5967     447
# 5968     447
# 5972     447
# 5986     447
# 5987     447
# 5988     447
# 5989     447
# 5990     447
# 5991     447
# 5992     447
# 5993     447
# 6000     447
# 6034     447
# 6043     447
# 6044     447
# 6138     447
# 6139     447
# 6141     447
# 6142     447
# 6147     447
# 6152     447
# 6160     447
# 6161     447
# 6162     447
# 6163     447
#         ...
# 12584    480
# 13047    486
# 13048    486
# 13060    486
# 13210    486
# 13211    486
# 13212    486
# 13343    486
# 13878    476
# 14039    476
# 15131    505
# 15322    505
# 15323    505
# 15324    505
# 15325    505
# 15326    505
# 15327    505
# 15328    505
# 15430    505
# 15561    505
# 15562    505
# 15605    505
# 16315    528
# 16316    528
# 16472    528
# 16485    528
# 16594    528
# 16595    528
# 16827    528
# 17394    528
# Name: followers, Length: 146, dtype: int32
# After 5962      894
# 5963      894
# 5964      894
# 5965      894
# 5966      894
# 5967      894
# 5968      894
# 5972      894
# 5986      894
# 5987      894
# 5988      894
# 5989      894
# 5990      894
# 5991      894
# 5992      894
# 5993      894
# 6000      894
# 6034      894
# 6043      894
# 6044      894
# 6138      894
# 6139      894
# 6141      894
# 6142      894
# 6147      894
# 6152      894
# 6160      894
# 6161      894
# 6162      894
# 6163      894
#          ...
# 12584     960
# 13047     972
# 13048     972
# 13060     972
# 13210     972
# 13211     972
# 13212     972
# 13343     972
# 13878     952
# 14039     952
# 15131    1010
# 15322    1010
# 15323    1010
# 15324    1010
# 15325    1010
# 15326    1010
# 15327    1010
# 15328    1010
# 15430    1010
# 15561    1010
# 15562    1010
# 15605    1010
# 16315    1056
# 16316    1056
# 16472    1056
# 16485    1056
# 16594    1056
# 16595    1056
# 16827    1056
# 17394    1056
# Name: followers, Length: 146, dtype: int32
# Before 8634     3233
# 8649     3233
# 8650     3233
# 8652     3233
# 8653     3233
# 8661     3233
# 8662     3233
# 8663     3233
# 8664     3233
# 8666     3233
# 8667     3233
# 8668     3233
# 8669     3233
# 8670     3233
# 8671     3233
# 8672     3233
# 8673     3233
# 8674     3233
# 8675     3233
# 13124    8374
# 13126    8374
# 13145    8374
# 13155    8374
# 13156    8374
# 13176    8374
# 13184    8374
# 13186    8374
#          ...
# 17044    9324
# 17047    9324
# 17061    9324
# 17070    9324
# 17075    9324
# 17078    9324
# 17079    9324
# 17130    9324
# 17269    9324
# 17270    9324
# 17286    9324
# 17332    9324
# 17333    9324
# 17334    9324
# 17335    9324
# 17336    9324
# 17342    9324
# 17344    9324
# 17345    9324
# 17346    9324
# 17352    9324
# 17358    9324
# 17360    9324
# 17369    9324
# 17370    9324
# 17373    9324
# 17375    9324
# 17381    9324
# 17383    9324
# 17386    9324
# Name: followers, Length: 397, dtype: int32
# Before 10721     62
# 10752     62
# 10758     62
# 10759     62
# 10760     62
# 10761     62
# 10762     62
# 10763     62
# 10764     62
# 10765     62
# 10766     62
# 10799     62
# 10801     62
# 10823     62
# 10832     62
# 10833     62
# 10888     62
# 10918     62
# 10972     62
# 10973     62
# 11031     62
# 11263     62
# 11264     62
# 11265     62
# 11347     62
# 11351     62
# 11354     62
# 11360     62
# 11370     62
# 11778     62
#         ...
# 14373    114
# 14374    114
# 14376    114
# 14384    114
# 14386    114
# 14389    114
# 14401    114
# 14411    114
# 14412    114
# 14421    114
# 14422    114
# 14440    114
# 14505    114
# 14517    114
# 14518    114
# 14576    114
# 14621    114
# 14622    114
# 14690    114
# 14701    114
# 14707    114
# 14710    114
# 14711    114
# 14733    114
# 14734    114
# 14735    114
# 14736    114
# 14775    114
# 14778    114
# 14951    114
# Name: followers, Length: 159, dtype: int32
# After 10721    124
# 10752    124
# 10758    124
# 10759    124
# 10760    124
# 10761    124
# 10762    124
# 10763    124
# 10764    124
# 10765    124
# 10766    124
# 10799    124
# 10801    124
# 10823    124
# 10832    124
# 10833    124
# 10888    124
# 10918    124
# 10972    124
# 10973    124
# 11031    124
# 11263    124
# 11264    124
# 11265    124
# 11347    124
# 11351    124
# 11354    124
# 11360    124
# 11370    124
# 11778    124
#         ...
# 14373    228
# 14374    228
# 14376    228
# 14384    228
# 14386    228
# 14389    228
# 14401    228
# 14411    228
# 14412    228
# 14421    228
# 14422    228
# 14440    228
# 14505    228
# 14517    228
# 14518    228
# 14576    228
# 14621    228
# 14622    228
# 14690    228
# 14701    228
# 14707    228
# 14710    228
# 14711    228
# 14733    228
# 14734    228
# 14735    228
# 14736    228
# 14775    228
# 14778    228
# 14951    228
# Name: followers, Length: 159, dtype: int32
# Before 10461    57
# 10462    57
# 10463    57
# 10464    57
# 10465    57
# 10466    57
# 10472    57
# 10473    57
# 10474    57
# 10475    57
# 10477    57
# 10485    57
# 10494    57
# 10495    57
# 10496    57
# 10497    57
# 10498    57
# 10499    57
# 10501    57
# 10502    57
# 10503    57
# 10504    57
# 10505    57
# 10506    57
# 10507    57
# 10508    57
# 10509    57
# 10510    57
# 10511    57
# 10512    57
# 10513    57
# 10515    57
# 10516    57
# 10517    57
# 10518    57
# 10519    57
# 10520    57
# 10521    57
# 10522    57
# 10523    57
# 10524    57
# 11201    207
# 11203    207
# 11204    207
# 11208    207
# 11216    207
# 11314    207
# 11318    207
# 11322    207
# 11324    207
# 11325    207
# 11326    207
# 11329    207
# 11332    207
# 11334    207
# 11336    207
# 11465    207
# 11466    207
# 11467    207
# 11468    207
# 11469    207
# 11471    207
# 11472    207
# 11473    207
# 11474    207
# 11475    207
#         ...
# 11526    207
# 11528    207
# 11529    207
# 11533    207
# 11534    207
# 11586    207
# 11589    207
# 11605    207
# 11612    207
# 11613    207
# 11616    207
# 11617    207
# 11619    207
# 11620    207
# 11622    207
# 11625    207
# 11626    207
# 11696    207
# 11697    207
# 11698    207
# 11772    207
# 11774    207
# 11788    207
# 11790    207
# 11792    207
# 11793    207
# 11797    207
# 11799    207
# 11811    207
# 11816    207
# Name: followers, Length: 68, dtype: int32
# After 11180    414
# 11182    414
# 11184    414
# 11187    414
# 11189    414
# 11201    414
# 11203    414
# 11204    414
# 11208    414
# 11216    414
# 11314    414
# 11318    414
# 11322    414
# 11324    414
# 11325    414
# 11326    414
# 11329    414
# 11332    414
# 11334    414
# 11336    414
# 11465    414
# 11466    414
# 11467    414
# 11468    414
# 11469    414
# 11471    414
# 11472    414
# 11473    414
# 11474    414
# 11475    414
#         ...
# 11526    414
# 11528    414
# 11529    414
# 11533    414
# 11534    414
# 11586    414
# 11589    414
# 11605    414
# 11612    414
# 11613    414
# 11616    414
# 11617    414
# 11619    414
# 11620    414
# 11622    414
# 11625    414
# 11626    414
# 11696    414
# 11697    414
# 11698    414
# 11772    414
# 11774    414
# 11788    414
# 11790    414
# 11792    414
# 11793    414
# 11797    414
# 11799    414
# 11811    414
# 11816    414
# Name: followers, Length: 68, dtype: int32
# Before 15914    944
# 15916    944
# 15917    944
# 15928    944
# 15929    944
# 15931    944
# 15935    944
# 15938    944
# 15947    944
# 15949    944
# 15951    944
# 15952    944
# 15957    944
# 15960    944
# 15961    944
# 15966    944
# 15972    944
# 15973    944
# 15974    944
# 15975    944
# 15976    944
# 15977    944
# 15978    944
# 15985    944
# 15986    944
# 15987    944
# 15988    944
# 15991    944
# 15994    944
# 15996    944
#         ...
# 16153    944
# 16154    944
# 16155    944
# 16156    944
# 16159    944
# 16162    944
# 16163    944
# 16164    944
# 16165    944
# 16166    944
# 16167    944
# 16168    944
# 16169    944
# 16170    944
# 16171    944
# 16173    944
# 16175    944
# 16176    944
# 16178    944
# 16180    944
# 16181    944
# 16182    944
# 16184    944
# 16185    944
# 16191    944
# 16193    944
# 16197    944
# 16202    944
# 16208    944
# 16210    944
# Name: followers, Length: 97, dtype: int32
# After 15914    1888
# 15916    1888
# 15917    1888
# 15928    1888
# 15929    1888
# 15931    1888
# 15935    1888
# 15938    1888
# 15947    1888
# 15949    1888
# 15951    1888
# 15952    1888
# 15957    1888
# 15960    1888
# 15961    1888
# 15966    1888
# 15972    1888
# 15973    1888
# 15974    1888
# 15975    1888
# 15976    1888
# 15977    1888
# 15978    1888
# 15985    1888
# 15986    1888
# Name: followers, Length: 193, dtype: int32
# Before 7869      169
# 7870      169
# 7871      169
# 7873      169
# 7874      169
# 7875      169
# 7882      169
# 7883      169
# 7884      169
# 7885      169
# 7886      169
# 7896      169
# 7897      169
# 7898      169
# 7906      169
# 7913      169
# 7914      169
# 7915      169
# 7916      169
# 7917      169
# 7919      169
# 8088      169
# 8101      169
# 8103      169
# 8136      169
# 8137      169
# 8142      169
# 8149      169
# 8151      169
# 8160      169
#          ...
# 15682    1398
# 15684    1398
# 15685    1398
# 15689    1398
# 15690    1398
# 15691    1398
# 15692    1398
# 15693    1398
# 15694    1398
# 15695    1398
# 15696    1398
# 15699    1398
# 15700    1398
# 15701    1398
# 16009    1398
# 16010    1398
# 16011    1398
# 16015    1398
# 16016    1398
# 16019    1398
# 16020    1398
# 16022    1398
# 16024    1398
# 16025    1398
# 16026    1398
# 16027    1398
# 16029    1398
# 16030    1398
# 16033    1398
# 16036    1398
# Name: followers, Length: 234, dtype: int32
# After 7869      338
# 7870      338
# 7871      338
# 7873      338
# 7874      338
# 7875      338
# 7882      338
# 7883      338
# 7884      338
# 7885      338
# 7886      338
# 7896      338
# 7897      338
# 7898      338
# 7906      338
# 7913      338
# 7914      338
# 7915      338
# 7916      338
# 7917      338
# 7919      338
# 8088      338
# 8101      338
# 8103      338
# 8136      338
# 8137      338
# 8142      338
# 8149      338
# 8151      338
# 8160      338
#          ...
# 15682    2796
# 15684    2796
# 15685    2796
# 15689    2796
# 15690    2796
# 15691    2796
# 15692    2796
# 15693    2796
# 15694    2796
# 15695    2796
# 15696    2796
# 15699    2796
# 15700    2796
# 15701    2796
# 16009    2796
# 16010    2796
# 16011    2796
# 16015    2796
# 16016    2796
# 16019    2796
# 16020    2796
# 16022    2796
# 16024    2796
# 16025    2796
# 16026    2796
# 16027    2796
# 16029    2796
# 16030    2796
# 16033    2796
# 16036    2796
# Name: followers, Length: 234, dtype: int32
# Before 4749    16
# 4891    16
# 4920    16
# 4970    16
# Name: followers, dtype: int32
# After 4749    32
# 4891    32
# 4920    32
# 4970    32
# Name: followers, dtype: int32
# Before 4417    214
# 4418    214
# 4419    214
# 4420    214
# 4421    214
# 4422    214
# 4423    214
# 4424    214
# 4425    214
# 4426    214
# 4427    214
# 4428    214
# 4429    214
# 4430    214
# 4431    214
# 4432    214
# 4433    214
# 4434    214
# 4453    214
# 4458    214
# 4459    214
# 4480    214
# 4481    214
# 4485    214
# 4489    214
# 4494    214
# 4506    214
# 4605    214
# 4606    214
# 4607    214
#        ...
# 4744    214
# 4745    214
# 4746    214
# 4747    214
# 4752    214
# 4771    214
# 4873    214
# 4874    214
# 4875    214
# 4895    214
# 4896    214
# 4897    214
# 4900    214
# 4901    214
# 4902    214
# 4903    214
# 4907    214
# 4908    214
# 4915    214
# 4971    214
# 4972    214
# 4975    214
# 4978    214
# 4980    214
# 4983    214
# 4984    214
# 5001    214
# 5019    214
# 5020    214
# 5021    214
# Name: followers, Length: 95, dtype: int32
# 17013    2964
# 17018    2964
# 17024    2964
# 17073    2964
# 17074    2964
# 17077    2964
# 17087    2964
# 17092    2964
# 17095    2964
# 17108    2964
# 17186    2964
# 17241    2964
# 17251    2964
# 17263    2964
# 17268    2964
# 17287    2964
# 17288    2964
# 17294    2964
# 17295    2964
# 17297    2964
# 17298    2964
# 17305    2964
# 17307    2964
# 17314    2964
# 17350    2964
# 17372    2964
# 17379    2964
# 17393    2964
# 17409    2964
# Name: followers, Length: 285, dtype: int32
# Before 11848    136
# 11850    136
# 11852    136
# 11854    136
# 11855    136
# 11894    136
# 11902    136
# 11933    136
# 11970    136
# 11974    136
# 11975    136
# 11976    136
# 11977    136
# 12003    136
# 12097    136
# 12100    136
# 12102    136
# 12107    136
# 12109    136
# 12110    136
# 12112    136
# 12138    136
# 12250    136
# 12251    136
# 12322    136
# 12323    136
# 12328    136
# 12330    136
# 12400    136
# 12402    136
# 12406    136
# 12407    136
# 12411    136
# 12413    136
# 12414    136
# 12419    136
# 12544    136
# 12545    136
# 12580    136
# 12581    136
# 12582    136
# 12588    136
# 12591    136
# 12592    136
# 12632    136
# 12730    136
# 12731    136
# Name: followers, dtype: int32
# After 11848    272
# 11850    272
# 11852    272
# 11854    272
# 11855    272
# 11894    272
# 11902    272
# 11933    272
# 11970    272
# 11974    272
# 11975    272
# 11976    272
# 11977    272
# 12003    272
# 12097    272
# 12100    272
# 12102    272
# 12107    272
# 12109    272
# 12110    272
# 12112    272
# 12138    272
# 12250    272
# 12251    272
# 12322    272
# 12323    272
# 12328    272
# 12330    272
# 12400    272
# 12402    272
# 12406    272
# 12407    272
# 12411    272
# 12413    272
# 12414    272
# 12419    272
# 12544    272
# 12545    272
# 12580    272
# 12581    272
# 12582    272
# 12588    272
# 12591    272
# 12592    272
# 12632    272
# 12730    272
# 12731    272
# Name: followers, dtype: int32
# Before 17098    268
# 17099    268
# 17131    268
# 17347    268
# 17349    268
# 17351    268
# 17353    268
# 17354    268
# 17355    268
# 17356    268
# 17357    268
# 17359    268
# 17361    268
# 17362    268
# 17363    268
# Name: followers, dtype: int32
# After 17098    536
# 17099    536
# 17131    536
# 17347    536
# 17349    536
# 17351    536
# 17353    536
# 17354    536
# 17355    536
# 17356    536
# 17357    536
# 17359    536
# 17361    536
# 17362    536
# 17363    536
# Name: followers, dtype: int32
# Before 1878     7152
# 1880     7152
# 1881     7152
# 1882     7152
# 1891     7152
# 1895     7152
# 1897     7152
# 1898     7152
# 1948     7152
# 1951     7152
# 1952     7152
# 1953     7152
# 1954     7152
# 1956     7152
# 1957     7152
# 1958     7152
# 1959     7152
# 1960     7152
# 1961     7152
# 1962     7152
# 1964     7152
# 1965     7152
# 1966     7152
# 1967     7152
# 1969     7152
# 1972     7152
# 1973     7152
# 1974     7152
# 1976     7152
# 1977     7152
#          ...
# 16494    7538
# 16557    7538
# 16563    7538
# 16606    7538
# 16721    7538
# 16722    7538
# 16946    7538
# 17003    7538
# 17004    7538
# 17005    7538
# 14935    193
# 14936    193
# 14937    193
# 14938    193
# 14939    193
# 14940    193
# Name: followers, dtype: int32
# After 14800    386
# 14856    386
# 14858    386
# 14859    386
# 14861    386
# 14867    386
# 14868    386
# 14871    386
# 14872    386
# 14873    386
# 14874    386
# 14880    386
# 14881    386
# 14883    386
# 14886    386
# 14890    386
# 14892    386
# 14896    386
# 14898    386
# 14900    386
# 14904    386
# 14905    386
# 14906    386
# 14907    386
# 14908    386
# 14909    386
# 14910    386
# 14911    386
# 14914    386
# 14926    386
# 14927    386
# 14928    386
# 14929    386
# 14931    386
# 14932    386
# 14934    386
# 14935    386
# 14936    386
# 14937    386
# 14938    386
# 14939    386
# 14940    386
# Name: followers, dtype: int32
# Before 9041     73
# 9043     73
# 9179     73
# 9180     73
# 9379     73
# 9491     73
# 9493     73
# 9494     73
# 9495     73
# 9496     73
# 9497     73
# 9498     73
# 9499     73
# 9533     73
# 9534     73
# 9562     73
# 9576     73
# 9586     73
# 9630     73
# 9654     73
# 9660     73
# 9688     73
# 10232    64
# Name: followers, dtype: int32
# After 9041     146
# 9043     146
# 9179     146
# 9180     146
# 9379     146
# 9491     146
# 9493     146
# 9494     146
# 9495     146
# 9496     146
# 9497     146
# 9498     146
# 9499     146
# 9533     146
# 9534     146
# 9562     146
# 9576     146
# 9586     146
# 9630     146
# 9654     146
# 9660     146
# 9688     146
# 10232    128
# Name: followers, dtype: int32
#                                                followers
# location
# .                                                    178
# 28th Street, Qamar Precint                        326580
# 40+Suspension for the truth!                        6049
# AP                                                 25375
# Al-Battar Media Foundatiom                         30000
# Among The Muslims                                  65174
# Among mushrikeen                                   38157
# Amsterdam, The Netherlands                          1935
# Antas, Bahia                                      315513
# Bandar Seri Begawan, Negara Brunei Darussalam      66896
# Dar Al Kufr                                         1582
# Don't need to know                                  3560
# Dunya                                             164890
# EU                                                 38315
# Earth                                              14304
# England, United Kingdom                             3533
# Gaziantep, Turkey                                 135112
# Geneva, Switzerland                               744944
# Germany                                          3537653
# Ghurabā                                            26011
# Guetto                                              6670
# I hate snitches                                     3773
# Islamic State                                       1556
# Lake City, GA                                      28220
# Land of Allah                                     183233
# Male'. Maldives.                                 1436761
# Middle of Nowhere                                 503121
# München, Deutschland                               52251
# Nowhere                                           465754
# Prison ( Darul Kufr )                                132
# Punch, Jammu And Kashmir                           40755
# Read my blog                                    93800585
# S.Wazirstan|Mahsud not a Wazir                    347166
# Singaparna, Indonesia                               7100
# Texas, USA                                       3378685
# United States                                    1589655
# Wilayah Kashmir                                    74641
# Wilayah Twitter                                   180937
# Wilayat Hadramaut                                 230538
# Worldwide contributions                          3537614
# dar al-kufr                                       811703
# darl mushrequeen                                   12831
# noway                                               8055
# world                                           17309793
# yamin, yasār raqum ١٤                               1670
# أسير الدنيا                                        82300
# اُمتِ مُسلمہ ولایت کشمیر                         2143575
# خارج الخلافة                                       16254
# سرت‎ Sirte                                          3363

# %% [markdown]
# Interpreting to fix the problem at the root

# %%
df['']

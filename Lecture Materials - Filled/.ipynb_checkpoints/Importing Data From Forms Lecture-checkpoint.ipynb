# %% [markdown]
# # Module X Lecture:  Importing Data from Forms

# %% [markdown]
# Open and Explore the Data File in a Word Processor

# %% [markdown]
# Open and view a single file in Python

# %%
with open('C:/users/mwbarr/Paypal Samples/AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190503054243.txt','r') as f:
    for line in f:
        print(line)
# Out:
#                            Global Investigations
#
#
#
#                            Law Enforcement Officer:                                                       Gardner, John SA
#
#
#
#                            Law Enforcement Agency:                                                        FBI - Manassas, VA
#
#
#
#                            Requested On:                                                                  Wed, 17 Apr 2019 16:40
#
#
#
#                            Evidence Gathered On:                                                          Fri, 03 May 2019 5:42
#
#
#
#                            Law Enforcement Reference:
#
#
#
#                            All times indicated in this document refer to time zone GMT
#
#
#
#                            Registration Information
#
#
#
#                            User Info
#
#
#
#                            First Name                                                                     Anlete
#
#
#
#                            Middle Name                                                                    Holos
#
#
#
#                            Last Name                                                                      Collado
#
#
#
#                            DOB                                                                            4-May-96
#
#
#
#                            CC Statement Name                                                              JOSECONQUER
#
#
#
#                            Email                                                                          joseconquer@hotmail.com
#
#
#
#                            Business Info
#
#
#
#                            Business Name
#
#
#
#                            URL
#
#
#
#                            Customer Service Phone
#
#
#
#                            Account Info
#
#
#
#                            Account Status                                                                 Limited - High
#
#
#
#                            Account #                                                                      2304074730245993858
#
#
#
#                            Account Type                                                                   Personal - DO Verified
#
#
#
#                            Time Created                                                                   Thu, 19 Jun 2014 12:55:03
#
#
#
#                            SSN
#
#
#
#                            SSN
#
#
#
#                            TIN
#
#
#
#                                                                                                                                 Email Addresses
#
#                            Email Address                                                                                                                              Primary                             Confirmed                           Active
#
#
#
#                            joseconquer@hotmail.com                                                                                                                    TRUE                                TRUE                                TRUE
#
#
#
#                                                                                                                                   Phone Numbers
#
#
#
#                            Phone Number                                                                   Confirmation Status                                                                             Type
#
#
#
#                            +1 8098783105                                                                  Confirmed                                                                                       Mobile - Deleted
#
#
#
#                            +1 8492153105                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 8496559263                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 8099350587                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 1                                                                           Unconfirmed                                                                                     Work - Deleted
#
#
#
#                            +1 8092541394                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 8093571394                                                                  Unconfirmed                                                                                     Mobile
#
#
#
#                            +1 8095838054                                                                  Unconfirmed                                                                                     Home - Deleted
#
#
#
#                                                                                                                                          Addresses
#
#
#
#                            Address                                                                                                                                    Use                                                                     Date Entered
#
#
#
#                            Anlete Collado, duarte #19 los peralejos, Santo Domingo                                                                                    Home Or Work                                                            05/01/19
#
#
#
#                            este, DN, DO 11708
#
#
#
#                            Bladimir gomez, 6930 NW 12th St , Miami, FL, US 33126-                                                                                     Gift (Hidden)                                                           10/30/18
#
#
#
#                            1303
#
#
#
#                            JULIO CESAR POLANCO, 8256 NW 68th ST , miami,                                                                                              Gift (Hidden)                                                           10/30/18
#
#
#
#                            FL, US 33166-2759
#
#
#
#                            Robinson Castillo, 8256 NW 68th St , Miami, FL, US                                                                                         Gift (Hidden)                                                           10/29/18
#
#
#
#                            33166-2759
#
#
#
#                            Robinson castillo, 8256 NW 68th ST Aim-22098, Miami,                                                                                       Gift (Hidden)                                                           10/26/18
#
#
#
#                            FL, US 33166
#
#
#
#                            Fatima Katiuska Collado LP-31-16911, 6930 NW 12th St                                                                                       Gift (Hidden)                                                           10/12/18
#
#
#
#                            LP-31-16911, Miami, FL, US 33126-1303
#
#
#
#                            Ismael Then Nuñez, 6930 NW 12Th St LP-31-15304,                                                                                            Gift (Hidden)                                                           01/04/18
#
#
#
#                            Miami, FL, US 33126-1303
#
#
#
#                            Anlete Collado, Santiago de los caballeros , Santiago de                                                                                                                                                           05/20/17
#
#
#
#                            los caballeros, SANTIAGO, DO 51000
#
#
#
#                            Financial Information
#
#
#
#                            Summary
#
#
#
#                            Account Balance                                                                USD 731.02 (Primary)
#
#
#
#                            Total Amount Sent                                                              USD 3,259.14 (Primary)
#
#                            Total Amount Received                                                          USD 5,627.32
#
#
#
#                            Amount Received Current Month
#
#
#
#                            Amount Received Month 1                                                        USD 25.12
#
#
#
#                            Amount Received Month 2                                                        USD 8.00
#
#
#
#                            Amount Received Month 3                                                        USD 9.08
#
#
#
#                            Pending Balance to be Released
#
#
#
#                                                                                                           $0.00 USD* (0 % - $0.00 USD)
#
#
#
#                            Minimum Reserve Balance
#
#
#
#                                                                                                           $0.00 USD* (0 % - 0 days)
#
#
#
#                            Rolling Reserve Balance
#
#
#
#                            Secure Card Attributes
#
#
#
#                            Billing Address
#
#
#
#                            Secure Card Numbers
#
#
#
#                            Backup Funding Source
#
#
#
#                            Daily Spending Limit
#
#
#
#                            PayPal Credit
#
#
#
#                            PP Credit Account Number
#
#
#
#                            Expiration Date
#
#
#
#                            Account Status
#
#
#
#                            Funding Source Availability
#
#
#
#                            Authorized Users
#
#
#
#                                                                                                                                    Bank Accounts
#
#
#
#                            Account #                                                                      Status                                                      Name                                Bank Info                           Routing #
#
#
#
#                            9600236000                                                                     INACTIVE                                                    Anlete Holos                                                            021000018
#
#
#
#                                                                                                                                                                       Collado
#
#
#
#                            Type                                                                           Bank Name                                                   Confirmed                                                               Country
#
#
#
#                            SAVINGS                                                                        BANK OF NEW YORK                                            Confirmation Not Supported                                              US
#
#
#
#                                                                                                           MELLON
#
#
#
#                                                                                                                                        Credit Cards
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5129925783481339                                                               INACTIVE-Expired                                            Anlete Collado                      10-Jun-18                           05/2019
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD DEBIT                                                              SANTANDER BANK, NA                                          Unconfirmed                                                             USD
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4303293640031172                                                               INACTIVE                                                    Anlete Collado                      2-Jun-17                            05/2021
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA DEBIT                                                                                                                                 Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5360581029644376                                                               INACTIVE                                                    Anlete Collado                      31-May-17                           10/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4482330012962593                                                               INACTIVE                                                    Anlete Collado                      5-May-18                            03/2022
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA DEBIT                                                                     TD Bank, National                                           Unconfirmed                                                             USD
#
#
#
#                                                                                                           Association
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5106216008782165                                                               INACTIVE-Expired                                            Anlete Collado                      3-Jun-17                            12/2017
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             RUB
#
#
#
#                            WORLD_SIGNIA
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4754917334280737                                                               INACTIVE                                                    Anlete Collado                      22-Sep-16                           04/2020
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA CREDIT GOLD                                                                                                                           Unconfirmed                                                             HNL
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4207670160221431                                                               INACTIVE-Expired                                            Anlete Collado                      10-Jun-18                           02/2019
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA DEBIT                                                                     CHASE PAY NET                                               Unconfirmed                                                             USD
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4912818001014020                                                               INACTIVE                                                    Anlete Collado                      7-Apr-18                            02/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                                                                                                           HSBC Mexico S.A.,
#
#
#
#                            VISA CREDIT GOLD                                                               Institucion de Banca                                        Unconfirmed                                                             MXN
#
#
#
#                                                                                                           Multiple, Grupo Financier
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4594130034271303                                                               INACTIVE                                                    Cristofer                           26-Oct-18                           04/2025
#
#
#
#                                                                                                                                                                       Collado
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA DEBIT                                                                                                                                 Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4147098143511467                                                               INACTIVE                                                    Anlete Collado                      10-Jun-18                           09/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#                            VISA CREDIT                                                                    Capital One Bank (Usa),                                     Unconfirmed                                                             USD
#
#
#
#                                                                                                           National Association
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5106390000583440                                                               INACTIVE                                                    Anlete Collado                      10-Jun-18                           05/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD DEBIT                                                              U.S. BANK NATIONAL                                          Unconfirmed                                                             USD
#
#
#
#                                                                                                           ASSOCIATION
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5360581032804546                                                               INACTIVE                                                    Anlete Collado                      18-Sep-17                           02/2022
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4303293310077653                                                               ACTIVE                                                      Fatima Collado                      26-Oct-18                           12/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA DEBIT                                                                                                                                 Unconfirmed:                                                            DOP
#
#
#
#                                                                                                                                                                       PayPal Code
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5360581031147152                                                               INACTIVE                                                    Anlete Collado                      20-May-17                           12/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5360581038696649                                                               INACTIVE                                                    Anlete Collado                      24-Feb-18                           11/2022
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5449270828558285                                                               INACTIVE                                                    Anlete Collado                      10-Jun-18                           06/2020
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD DEBIT                                                              KEYBANK NATIONAL                                            Unconfirmed                                                             USD
#
#
#
#                                                                                                           ASSOCIATION
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5106211006019702                                                               INACTIVE-Expired                                            Anlete Collado                      3-Jun-17                            01/2018
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             RUB
#
#
#
#                            WORLD_SIGNIA
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5290919100833788                                                               INACTIVE                                                    Anlete Collado                      7-Apr-18                            01/2022
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                      GOLD                   BANAMEX                                                     Unconfirmed                                                             MXN
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5360581039425477                                                               INACTIVE                                                    Anlete Collado                      26-Oct-18                           01/2023
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4213644047714456                                                               INACTIVE                                                    Anlete Collado                      14-Aug-16                           06/2019
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA CREDIT                                                                    Promocion y Operacion,                                      Unconfirmed                                                             MXN
#
#
#
#                                                                                                           S.A. de C.V.
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4154179435944788                                                               INACTIVE                                                    Anlete Collado                      10-Jun-18                           11/2021
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA CREDIT                                                                    Capital One Bank (Usa),                                     Unconfirmed                                                             USD
#
#
#
#                                                                                                           National Association
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5360581039016375                                                               INACTIVE                                                    Anlete Collado                      26-Oct-18                           11/2022
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD CREDIT                                                                                                                         Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4573177205938074                                                               INACTIVE                                                    Anlete Collado                      3-Nov-17                            11/2020
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA CREDIT INFINITE                                                                                                                       Unconfirmed                                                             COP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            4594130021364707                                                               INACTIVE                                                    Anlete Collado                      6-Oct-17                            06/2022
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            VISA DEBIT                                                                                                                                 Unconfirmed                                                             DOP
#
#
#
#                            Account #                                                                      Status                                                      Name                                Start Date                          Expiration                 Date
#
#
#
#                            5256781603016796                                                               INACTIVE                                                    Anlete Collado                      7-Apr-18                            12/2019
#
#
#
#                            Type                                                                           Issuer                                                      Confirmed                           Issue #                             Currency
#
#
#
#                            MASTER_CARD DEBIT                                                              BANAMEX                                                     Unconfirmed                                                             MXN
#
#
#
#                                                                                                                                         Debit Cards
#
#
#
#                                                                                                                                        Restrictions
#
#
#
#                            Restriction                                                                    Time Restricted                                             Time Lifted                                                             Attack Case ID
#
#
#
#                            Unauthorized Account Access                                                    Mon, 29 Oct 2018 2:31:22                                    Mon, 29 Oct 2018 2:35:13                                                PP-007-463-
#
#
#
#                                                                                                                                                                                                                                               310-971
#
#                            SRO - High Risk Selling Activity                                               Thu, 01 Nov 2018                                                                                                                    PP-007-475-
#
#
#
#                                                                                                           12:18:34                                                                                                                            759-197
#
#
#
#                            This document is sent electronically and does not require any signature.
#
#
#
#                            The information in this document has been processed based on the request from the Law Enforcement Officer named
#
#
#
#                            above.
#
#
#
#                                  CONFIDENTIALITY NOTICE:
#
#
#
#                            This communication with its contents may contain confidential and/or legally privileged information. It is
#
#
#
#                            solely for the use of the intended recipient(s). Unauthorized interception, review, use or disclosure is
#
#
#
#                            prohibited and may violate applicable laws including the Electronic Communications Privacy Act. If you are
#
#
#
#                            not the intended recipient, please contact the sender and destroy all copies of the communication.

# %% [markdown]
# Extracting first name, last name, and DOB from file

# %%
with open('C:/users/mwbarr/Paypal Samples/AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190503054243.txt','r') as f:
    for line in f:
        if 'First Name' in line:
            firstName=line
        if 'Last Name' in line:
            lastName=line
        if 'DOB' in line:
            dob=line
firstName,lastName,dob
# Out:
# ('                           First Name                                                                     Anlete\n',
#  '                           Last Name                                                                      Collado\n',
#  '                           DOB                                                                            4-May-96\n')

# %% [markdown]
# Cleaning Text

# %%
cleanedFirstName=firstName.replace('First Name','').strip()
cleanedLastName=lastName.replace('Last Name','').strip()
cleanedDob=dob.replace('DOB','').strip()
cleanedFirstName,cleanedLastName,cleanedDob
# Out:
# ('Anlete', 'Collado', '4-May-96')

# %% [markdown]
# Locating Nested Tables using Key Terms and Toggles

# %%
inPhoneNumbersSection=False
with open('C:/users/mwbarr/Paypal Samples/AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190503054243.txt','r') as f:
    for line in f:
        if 'Addresses' in line:
            inPhoneNumbersSection=False
        if inPhoneNumbersSection==True:
            print(line)
        if 'Phone Numbers' in line:
            inPhoneNumbersSection=True
# Out:
#                            Phone Number                                                                   Confirmation Status                                                                             Type
#
#
#
#                            +1 8098783105                                                                  Confirmed                                                                                       Mobile - Deleted
#
#
#
#                            +1 8492153105                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 8496559263                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 8099350587                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 1                                                                           Unconfirmed                                                                                     Work - Deleted
#
#
#
#                            +1 8092541394                                                                  Unconfirmed                                                                                     Mobile - Deleted
#
#
#
#                            +1 8093571394                                                                  Unconfirmed                                                                                     Mobile
#
#
#
#                            +1 8095838054                                                                  Unconfirmed                                                                                     Home - Deleted

# %% [markdown]
# Storing Data from Nested Tables

# %%
inPhoneNumbersSection=False
phoneNumberRows=[]
with open('C:/users/mwbarr/Paypal Samples/AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190503054243.txt','r') as f:
    for line in f:
        if 'Addresses' in line:
            inPhoneNumbersSection=False
        if inPhoneNumbersSection==True:
            if len(line)>10:
                phoneNumberRows.append(line.split())
        if 'Phone Numbers' in line:
            inPhoneNumbersSection=True
phoneNumberRows
# Out:
# [['Phone', 'Number', 'Confirmation', 'Status', 'Type'],
#  ['+1', '8098783105', 'Confirmed', 'Mobile', '-', 'Deleted'],
#  ['+1', '8492153105', 'Unconfirmed', 'Mobile', '-', 'Deleted'],
#  ['+1', '8496559263', 'Unconfirmed', 'Mobile', '-', 'Deleted'],
#  ['+1', '8099350587', 'Unconfirmed', 'Mobile', '-', 'Deleted'],
#  ['+1', '1', 'Unconfirmed', 'Work', '-', 'Deleted'],
#  ['+1', '8092541394', 'Unconfirmed', 'Mobile', '-', 'Deleted'],
#  ['+1', '8093571394', 'Unconfirmed', 'Mobile'],
#  ['+1', '8095838054', 'Unconfirmed', 'Home', '-', 'Deleted']]

# %% [markdown]
# Convert Extracted Data to Data Frame

# %%
import pandas as pd
phoneNumbers=pd.DataFrame(phoneNumberRows)
phoneNumbers
# Out:
#        0           1             2       3     4        5
# 0  Phone      Number  Confirmation  Status  Type     None
# 1     +1  8098783105     Confirmed  Mobile     -  Deleted
# 2     +1  8492153105   Unconfirmed  Mobile     -  Deleted
# 3     +1  8496559263   Unconfirmed  Mobile     -  Deleted
# 4     +1  8099350587   Unconfirmed  Mobile     -  Deleted
# 5     +1           1   Unconfirmed    Work     -  Deleted
# 6     +1  8092541394   Unconfirmed  Mobile     -  Deleted
# 7     +1  8093571394   Unconfirmed  Mobile  None     None
# 8     +1  8095838054   Unconfirmed    Home     -  Deleted

# %% [markdown]
# Change Column Headers, then drop the first row

# %%
phoneNumbers.columns=['Country Code','Number','Confirmation','Type','Additional Info','Deleted']
phoneNumbers=phoneNumbers.drop(0)
phoneNumbers
# Out:
#   Country Code      Number Confirmation    Type Additional Info  Deleted
# 1           +1  8098783105    Confirmed  Mobile               -  Deleted
# 2           +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 3           +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 4           +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 5           +1           1  Unconfirmed    Work               -  Deleted
# 6           +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 7           +1  8093571394  Unconfirmed  Mobile            None     None
# 8           +1  8095838054  Unconfirmed    Home               -  Deleted

# %% [markdown]
# Listing Files in a folder

# %%
import os
files=os.listdir('C:/users/mwbarr/Paypal Samples')
files
# Out:
# ['AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190503054243.txt',
#  'AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190506110341.txt',
#  'AccountInfo-joseconquer@hotmail.com-2304074730245993858-20190510151807.txt',
#  'AccountInfo-nestellerluisreyes@gmail.com-1949742777572609669-20190503045620.txt',
#  'AccountInfo-nestellerluisreyes@gmail.com-1949742777572609669-20190503060131.txt',
#  'AccountInfo-nestellerluisreyes@gmail.com-1949742777572609669-20190510153503.txt']

# %% [markdown]
# Putting Bio Info from Multiple Files Together

# %%
firstNames=[]
lastNames=[]
dobs=[]
for file in files:
    with open('C:/users/mwbarr/Paypal Samples/'+file,'r') as f:
        for line in f:
            if 'First Name' in line:
                firstName=line
            if 'Last Name' in line:
                lastName=line
            if ' DOB ' in line:
                dob=line
        cleanedFirstName=firstName.replace('First Name','').strip()
        cleanedLastName=lastName.replace('Last Name','').strip()
        cleanedDob=dob.replace('DOB','').strip()
        firstNames.append(cleanedFirstName)
        lastNames.append(cleanedLastName)
        dobs.append(cleanedDob)
firstNames,lastNames,dobs
# Out:
# (['Anlete', 'Anlete', 'Anlete', 'Luis', 'Luis', 'Luis'],
#  ['Collado',
#   'Collado',
#   'Collado',
#   'Reyes Solera',
#   'Reyes Solera',
#   'Reyes Solera'],
#  ['4-May-96', '4-May-96', '4-May-96', '27-May-95', '27-May-95', '27-May-95'])

# %% [markdown]
# Convert Bio Info to Dataframe

# %%
bioDf=pd.DataFrame({'First Name':firstNames,'Last Name':lastNames,'DOB':dobs})
bioDf
# Out:
#          DOB First Name     Last Name
# 0   4-May-96     Anlete       Collado
# 1   4-May-96     Anlete       Collado
# 2   4-May-96     Anlete       Collado
# 3  27-May-95       Luis  Reyes Solera
# 4  27-May-95       Luis  Reyes Solera
# 5  27-May-95       Luis  Reyes Solera

# %% [markdown]
# Concatenating Phone Number Tables

# %%
phoneNumbers=pd.DataFrame()
for file in files:
    with open('C:/users/mwbarr/Paypal Samples/'+file,'r') as f:
        for line in f:
            if 'Addresses' in line:
                inPhoneNumbersSection=False
            if inPhoneNumbersSection==True:
                if len(line)>10:
                    phoneNumberRows.append(line.split())
            if 'Phone Numbers' in line:
                inPhoneNumbersSection=True
    phoneNumbers=pd.concat([phoneNumbers,pd.DataFrame(phoneNumberRows)])

phoneNumbers.columns=['Country Code','Number','Confirmation','Type','Additional Info','Deleted']
phoneNumbers=phoneNumbers[phoneNumbers['Number']!='Number']
phoneNumbers
# Out:
#     Country Code      Number Confirmation    Type Additional Info  Deleted
# 1             +1  8098783105    Confirmed  Mobile               -  Deleted
# 2             +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 3             +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 4             +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 5             +1           1  Unconfirmed    Work               -  Deleted
# 6             +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 7             +1  8093571394  Unconfirmed  Mobile            None     None
# 8             +1  8095838054  Unconfirmed    Home               -  Deleted
# 10            +1  8098783105    Confirmed  Mobile               -  Deleted
# 11            +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 12            +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 13            +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 14            +1           1  Unconfirmed    Work               -  Deleted
# 15            +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 16            +1  8093571394  Unconfirmed  Mobile            None     None
# 17            +1  8095838054  Unconfirmed    Home               -  Deleted
# 19            +1  8098783105    Confirmed  Mobile               -  Deleted
# 20            +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 21            +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 22            +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 23            +1           1  Unconfirmed    Work               -  Deleted
# 24            +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 25            +1  8093571394  Unconfirmed  Mobile            None     None
# 26            +1  8095838054  Unconfirmed    Home               -  Deleted
# 28            +1  8098783105    Confirmed  Mobile               -  Deleted
# 29            +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 30            +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 31            +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 32            +1           1  Unconfirmed    Work               -  Deleted
# 33            +1  8092541394  Unconfirmed  Mobile               -  Deleted
# ..           ...         ...          ...     ...             ...      ...
# 112           +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 113           +1           1  Unconfirmed    Work               -  Deleted
# 114           +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 115           +1  8093571394  Unconfirmed  Mobile            None     None
# 116           +1  8095838054  Unconfirmed    Home               -  Deleted
# 118           +1  8098783105    Confirmed  Mobile               -  Deleted
# 119           +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 120           +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 121           +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 122           +1           1  Unconfirmed    Work               -  Deleted
# 123           +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 124           +1  8093571394  Unconfirmed  Mobile            None     None
# 125           +1  8095838054  Unconfirmed    Home               -  Deleted
# 127           +1  8098783105    Confirmed  Mobile               -  Deleted
# 128           +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 129           +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 130           +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 131           +1           1  Unconfirmed    Work            None     None
# 132           +1  8095838054  Unconfirmed    Home               -  Deleted
# 134           +1  8098783105    Confirmed  Mobile               -  Deleted
# 135           +1  8492153105  Unconfirmed  Mobile               -  Deleted
# 136           +1  8496559263  Unconfirmed  Mobile               -  Deleted
# 137           +1  8099350587  Unconfirmed  Mobile               -  Deleted
# 138           +1           1  Unconfirmed    Work               -  Deleted
# 139           +1  8092541394  Unconfirmed  Mobile               -  Deleted
# 140           +1  8093571394  Unconfirmed  Mobile            None     None
# 141           +1  8095838054  Unconfirmed    Home               -  Deleted
# 143          +57  3107486151  Unconfirmed  Mobile            None     None
# 145          +57  3107486151  Unconfirmed  Mobile            None     None
# 147          +57  3107486151  Unconfirmed  Mobile            None     None
#
# [740 rows x 6 columns]

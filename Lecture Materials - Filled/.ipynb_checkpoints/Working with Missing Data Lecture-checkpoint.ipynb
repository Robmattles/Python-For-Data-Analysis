# %% [markdown]
# # Module 6 - Working with Missing Data

# %% [markdown]
# Import and Read Data

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'C:\Users\mwbarr\Python for Data Analysis\Data Files\isistweetsenhanced.csv')

# %% [markdown]
# Brief Exploratory Analysis

# %%
df.shape
# Out:
# (17410, 16)

# %%
df.head()
# Out:
#    Unnamed: 0           name         username  \
# 0           0  GunsandCoffee  GunsandCoffee70
# 1           1  GunsandCoffee  GunsandCoffee70
# 2           2  GunsandCoffee  GunsandCoffee70
# 3           3  GunsandCoffee  GunsandCoffee70
# 4           4  GunsandCoffee  GunsandCoffee70
#
#                                     description location  followers  \
# 0  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 1  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 2  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 3  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
# 4  ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews      NaN        640
#
#    numberstatuses            time  \
# 0              49  1/6/2015 21:07
# 1              49  1/6/2015 21:27
# 2              49  1/6/2015 21:29
# 3              49  1/6/2015 21:37
# 4              49  1/6/2015 21:45
#
# ...

# %% [markdown]
# Find Null values

# %%
df['location'].isnull().head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: location, dtype: bool

# %% [markdown]
# Count/get percentage of  null values

# %%
df['location'].isnull().mean()
# Out:
# 0.343365881677197

# %% [markdown]
# Subset on null values

# %%
df[df['location'].notnull()]
# Out:
#        Unnamed: 0                name         username  \
# 29             29  Abu Layth Al Hindi  AbuLaythAlHindi
# 30             30  Abu Layth Al Hindi  AbuLaythAlHindi
# 332           332        War Reporter     warreporter2
# 333           333        War Reporter     warreporter2
# 422           422        War Reporter     warreporter2
# 423           423        War Reporter     warreporter2
# 424           424        War Reporter     warreporter2
# 442           442        War Reporter     warreporter2
# 443           443        War Reporter     warreporter2
# 444           444        War Reporter     warreporter2
# 445           445        War Reporter     warreporter2
# 446           446        War Reporter     warreporter2
# 515           515        War Reporter     warreporter2
# 516           516        War Reporter     warreporter2
# 517           517        War Reporter     warreporter2
# 552           552        War Reporter     warreporter2
# ...

# %% [markdown]
# Filling missing values with constants, bfill, and other columns (including other columns created dynamically)

# %%
df=df['location'].fillna(method='bfill')

# %%
df['test']=pd.Series(['']*len(df))
df['test'].isnull().sum()
# Out:
# 0

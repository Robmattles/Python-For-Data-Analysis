# %% [markdown]
# # Module 4 Exercise - Core Pandas Concepts

# %% [markdown]
# ### Prelude - Importing Libraries
# Typically, it's best practice to import all of the packages (aka libraries) that you will need for a notebook/script/project right at the beginning.  For almost all data-related projects, you will start by importing numpy (numerical Python) and Pandas.  Its traditional to abbrieviate these two libraries as np and pd respectively, using the 'as' keyword.
#
# **In the below cell, import numpy and pandas as np and pd respectively**

# %%
##Your code here

# %% [markdown]
# ### Part 1:  Reading Data
#
# In the below section, you will read and write data to/from pandas dataframes.  The files you will be reading from have the same data, but slightly different quirks that will necessitate slightly different approaches to reading the data.  Feel free to open the files in Excel to see what these quirks might be, and, as always, use Google to seek resources.

# %% [markdown]
# **1a.**  Read the file enronEnriched.csv from the Module 4 folder into a pandas dataframe

# %%
df=pd.read_csv(r'C:\Users\mwbarr\OneDrive - Federal Bureau of Investigation\Python_for_Data_Analysis\Python for Data Analysis\Module 4\enronEnriched.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                     Message-ID  \
# 0           0        500000  <30866805.1075852350908.JavaMail.evans@thyme>
# 1           1        500001  <26879196.1075852350962.JavaMail.evans@thyme>
# 2           2        500002  <15339082.1075852350988.JavaMail.evans@thyme>
# 3           3        500003   <5265469.1075852351013.JavaMail.evans@thyme>
# 4           4        500004  <13706905.1075852351066.JavaMail.evans@thyme>
#
#                   Date                                      From  \
# 0  2001-07-13 19:47:20     frozenset({'donna.fulton@enron.com'})
# 1  2001-07-12 11:36:58   frozenset({'david.delainey@enron.com'})
# 2  2001-07-10 00:47:51    frozenset({'jeff.dasovich@enron.com'})
# 3  2001-07-06 20:45:05  frozenset({'richard.shapiro@enron.com'})
# 4  2001-07-06 20:44:33  frozenset({'richard.shapiro@enron.com'})
#
#                                                   To  \
# 0  frozenset({'david.fairley@enron.com', 'matt.lo...
# 1  frozenset({'john.greg@enron.com', 'jeff.skilli...
# 2  frozenset({'linda.robertson@enron.com', 'harry...
# 3  frozenset({'greg.whalley@enron.com', 'john.lav...
# 4  frozenset({'greg.whalley@enron.com', 'john.lav...
#
#                                              Subject  \
# 0  RTO Orders - Grid South, SE Trans, SPP and Ent...
# 1                                   More UC/CSU Info
# 2                         California Update 07.09.01
# 3        Davis & Company -- incompetence personified
# 4                          Link to DWR contract info
#
#                                               X-From  \
# 0  Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1  Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2  Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                                 X-To X-cc  ... Cat_10_weight  \
# 0  Kean, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...  NaN  ...           NaN
# 1  Greg Whalley/HOU/ECT@ENRON, Lavorato, John </O...  NaN  ...           NaN
# 2  skean@enron.com, Shapiro, Richard </O=ENRON/OU...  NaN  ...           NaN
# 3  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN  ...           NaN
# 4  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN  ...           NaN
#
#   Cat_11_level_1 Cat_11_level_2 Cat_11_weight Cat_12_level_1 Cat_12_level_2  \
# 0            NaN            NaN           NaN            NaN            NaN
# 1            NaN            NaN           NaN            NaN            NaN
# 2            NaN            NaN           NaN            NaN            NaN
# 3            NaN            NaN           NaN            NaN            NaN
# 4            NaN            NaN           NaN            NaN            NaN
#
#    Cat_12_weight  labeled  dollarValueMentionedinMessage  messageLength
# 0            NaN    False                            NaN           2570
# 1            NaN    False                            NaN           3761
# 2            NaN    False                            NaN           1348
# 3            NaN    False                           37.0           2592
# 4            NaN    False                           43.0           1774
#
# [5 rows x 55 columns]

# %% [markdown]
# **1b.** Read the file enronEnrichedNonLatin.csv from the Module 4 folder into a pandas dataframe. This file has strange characters

# %%
df1b=pd.read_csv(r'C:\Users\mwbarr\OneDrive - Federal Bureau of Investigation\Python_for_Data_Analysis\Python for Data Analysis\Module 4\enronEnrichedNonLatin.csv', encoding='ISO-8859-1')
df1b.head()
# Out:
#    Index Unnamed: 0                                                 To  \
# 0      0          ®  frozenset({'david.fairley@enron.com', 'matt.lo...
# 1      1          ®  frozenset({'john.greg@enron.com', 'jeff.skilli...
# 2      2          ®  frozenset({'linda.robertson@enron.com', 'harry...
# 3      3          ®  frozenset({'greg.whalley@enron.com', 'john.lav...
# 4      4          ®  frozenset({'greg.whalley@enron.com', 'john.lav...
#
#                                              Subject  \
# 0  RTO Orders - Grid South, SE Trans, SPP and Ent...
# 1                                   More UC/CSU Info
# 2                         California Update 07.09.01
# 3        Davis & Company -- incompetence personified
# 4                          Link to DWR contract info
#
#                                               X-From  \
# 0  Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1  Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2  Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                                 X-To X-cc  X-bcc  \
# 0  Kean, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...  NaN    NaN
# 1  Greg Whalley/HOU/ECT@ENRON, Lavorato, John </O...  NaN    NaN
# 2  skean@enron.com, Shapiro, Richard </O=ENRON/OU...  NaN    NaN
# 3  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN    NaN
# 4  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN    NaN
#
#                             X-Folder   X-Origin  ... Cat_10_weight  \
# 0  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  ...           NaN
# 1  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  ...           NaN
# 2  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  ...           NaN
# 3  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  ...           NaN
# 4  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  ...           NaN
#
#   Cat_11_level_1 Cat_11_level_2  Cat_11_weight  Cat_12_level_1  \
# 0            NaN            NaN            NaN             NaN
# 1            NaN            NaN            NaN             NaN
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#    Cat_12_level_2  Cat_12_weight  labeled  dollarValueMentionedinMessage  \
# 0             NaN            NaN    False                            NaN
# 1             NaN            NaN    False                            NaN
# 2             NaN            NaN    False                            NaN
# 3             NaN            NaN    False                           37.0
# 4             NaN            NaN    False                           43.0
#
#    messageLength
# 0           2570
# 1           3761
# 2           1348
# 3           2592
# 4           1774
#
# [5 rows x 52 columns]

# %% [markdown]
# **1c.** Read the file enronEnrichedWithClass.csv from the Module 4 folder into a pandas dataframe.  This file has a fake classification banner in the first row.

# %%
df1c=pd.read_csv(r'C:\Users\mwbarr\OneDrive - Federal Bureau of Investigation\Python_for_Data_Analysis\Python for Data Analysis\Module 4\enronEnrichedWithClass.csv', skiprows=1)
df1c.head()
# Out:
#    Index  Unnamed: 0                                     Message-ID  \
# 0      0      500000  <30866805.1075852350908.JavaMail.evans@thyme>
# 1      1      500001  <26879196.1075852350962.JavaMail.evans@thyme>
# 2      2      500002  <15339082.1075852350988.JavaMail.evans@thyme>
# 3      3      500003   <5265469.1075852351013.JavaMail.evans@thyme>
# 4      4      500004  <13706905.1075852351066.JavaMail.evans@thyme>
#
#               Date                                      From  \
# 0  7/13/2001 19:47     frozenset({'donna.fulton@enron.com'})
# 1  7/12/2001 11:36   frozenset({'david.delainey@enron.com'})
# 2   7/10/2001 0:47    frozenset({'jeff.dasovich@enron.com'})
# 3   7/6/2001 20:45  frozenset({'richard.shapiro@enron.com'})
# 4   7/6/2001 20:44  frozenset({'richard.shapiro@enron.com'})
#
#                                                   To  \
# 0  frozenset({'david.fairley@enron.com', 'matt.lo...
# 1  frozenset({'john.greg@enron.com', 'jeff.skilli...
# 2  frozenset({'linda.robertson@enron.com', 'harry...
# 3  frozenset({'greg.whalley@enron.com', 'john.lav...
# 4  frozenset({'greg.whalley@enron.com', 'john.lav...
#
#                                              Subject  \
# 0  RTO Orders - Grid South, SE Trans, SPP and Ent...
# 1                                   More UC/CSU Info
# 2                         California Update 07.09.01
# 3        Davis & Company -- incompetence personified
# 4                          Link to DWR contract info
#
#                                               X-From  \
# 0  Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1  Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2  Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                                 X-To X-cc  ...  Cat_10_weight  \
# 0  Kean, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...  NaN  ...            NaN
# 1  Greg Whalley/HOU/ECT@ENRON, Lavorato, John </O...  NaN  ...            NaN
# 2  skean@enron.com, Shapiro, Richard </O=ENRON/OU...  NaN  ...            NaN
# 3  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN  ...            NaN
# 4  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN  ...            NaN
#
#   Cat_11_level_1 Cat_11_level_2 Cat_11_weight Cat_12_level_1 Cat_12_level_2  \
# 0            NaN            NaN           NaN            NaN            NaN
# 1            NaN            NaN           NaN            NaN            NaN
# 2            NaN            NaN           NaN            NaN            NaN
# 3            NaN            NaN           NaN            NaN            NaN
# 4            NaN            NaN           NaN            NaN            NaN
#
#    Cat_12_weight  labeled  dollarValueMentionedinMessage  messageLength
# 0            NaN    False                            NaN           2570
# 1            NaN    False                            NaN           3761
# 2            NaN    False                            NaN           1348
# 3            NaN    False                           37.0           2592
# 4            NaN    False                           43.0           1774
#
# [5 rows x 55 columns]

# %% [markdown]
# **1d** Read the second and third sheets of enronEnriched**.xlsx** into a pandas dataframe.

# %%
secondSheet=pd.read_excel(r'C:\Users\mwbarr\OneDrive - Federal Bureau of Investigation\Python_for_Data_Analysis\Python for Data Analysis\Module 4\enronEnriched.xlsx', sheet_name=1)
print(secondSheet.shape)
thirdSheet=pd.read_excel(r'C:\Users\mwbarr\OneDrive - Federal Bureau of Investigation\Python_for_Data_Analysis\Python for Data Analysis\Module 4\enronEnriched.xlsx', sheet_name=2)
print(thirdSheet.shape)
# Out:
# (15, 55)
# (8, 55)

# %% [markdown]
# ### Part 2:  Performing Basic Cleaning Operations

# %% [markdown]
# **2a** Remove all columns from the data frame except for the following:  'Subject', 'X-From', 'X-To', 'X-cc',
#        'X-bcc', 'X-Folder', 'X-Origin', 'X-FileName', 'content', 'user', 'labeled', 'dollarValueMentionedinMessage', 'messageLength'

# %%
##Your code here
df=df[[ 'Subject', 'X-From', 'X-To', 'X-cc', 'X-bcc', 'X-Folder', 'X-Origin', 'X-FileName', 'content', 'user', 'labeled', 'dollarValueMentionedinMessage', 'messageLength']]
df.head()
# Out:
#                                              Subject  \
# 0  RTO Orders - Grid South, SE Trans, SPP and Ent...
# 1                                   More UC/CSU Info
# 2                         California Update 07.09.01
# 3        Davis & Company -- incompetence personified
# 4                          Link to DWR contract info
#
#                                               X-From  \
# 0  Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1  Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2  Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                                 X-To X-cc X-bcc  \
# 0  Kean, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...  NaN   NaN
# 1  Greg Whalley/HOU/ECT@ENRON, Lavorato, John </O...  NaN   NaN
# 2  skean@enron.com, Shapiro, Richard </O=ENRON/OU...  NaN   NaN
# 3  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN   NaN
# 4  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN   NaN
#
#                             X-Folder   X-Origin                    X-FileName  \
# 0  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 1  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 2  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 3  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 4  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
#
#                                              content       user  labeled  \
# 0  The Southeast RTO orders are out and have foll...  whalley-g    False
# 1  ---------------------- Forwarded by David W De...  whalley-g    False
# 2  The Bond Legislation The Democrats in the Asse...  whalley-g    False
# 3  FYI ---------------------- Forwarded by Richar...  whalley-g    False
# 4  FYI ---------------------- Forwarded by Richar...  whalley-g    False
#
#    dollarValueMentionedinMessage  messageLength
# 0                            NaN           2570
# 1                            NaN           3761
# 2                            NaN           1348
# 3                           37.0           2592
# 4                           43.0           1774

# %% [markdown]
# **2b** Rename the columns, removing the "X-" from all columns starting with "X-"

# %%
##Your code here
df.columns=[colName.replace('X-','') for colName in df.columns]
df.head()
# Out:
#                                              Subject  \
# 0  RTO Orders - Grid South, SE Trans, SPP and Ent...
# 1                                   More UC/CSU Info
# 2                         California Update 07.09.01
# 3        Davis & Company -- incompetence personified
# 4                          Link to DWR contract info
#
#                                                 From  \
# 0  Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1  Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2  Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                                   To   cc  bcc  \
# 0  Kean, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...  NaN  NaN
# 1  Greg Whalley/HOU/ECT@ENRON, Lavorato, John </O...  NaN  NaN
# 2  skean@enron.com, Shapiro, Richard </O=ENRON/OU...  NaN  NaN
# 3  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN  NaN
# 4  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...  NaN  NaN
#
#                               Folder     Origin                      FileName  \
# 0  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 1  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 2  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 3  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 4  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
#
#                                              content       user  labeled  \
# 0  The Southeast RTO orders are out and have foll...  whalley-g    False
# 1  ---------------------- Forwarded by David W De...  whalley-g    False
# 2  The Bond Legislation The Democrats in the Asse...  whalley-g    False
# 3  FYI ---------------------- Forwarded by Richar...  whalley-g    False
# 4  FYI ---------------------- Forwarded by Richar...  whalley-g    False
#
#    dollarValueMentionedinMessage  messageLength
# 0                            NaN           2570
# 1                            NaN           3761
# 2                            NaN           1348
# 3                           37.0           2592
# 4                           43.0           1774

# %% [markdown]
# ### Part 3 - Basic Exploratory Data Analysis

# %% [markdown]
# **3a**  Get the number of rows and columns from the dataframe (called df) that you worked with in part 2

# %%
numberOfRows=df.shape[0]
numberOfColumns=df.shape[1]
print('Dataframe has ',numberOfRows,' rows ',numberOfColumns,' columns')
# Out:
# Dataframe has  17401  rows  13  columns

# %% [markdown]
# **3b** Use the describe function to get summary statistics for each column of the dataframe (still using df from 1a)

# %%
df.describe()
##Your code here
# Out:
#        dollarValueMentionedinMessage  messageLength
# count                   2.244000e+03   17401.000000
# mean                    3.048070e+06    1222.784150
# std                     3.786289e+07    2723.022246
# min                     0.000000e+00       1.000000
# 25%                     7.000000e+00     174.000000
# 50%                     5.000000e+01     508.000000
# 75%                     4.950000e+02    1302.000000
# max                     9.864142e+08   97845.000000

# %% [markdown]
# **3c** Use the info function to get a different summary of the dataframe

# %%
##Your code here

# %% [markdown]
# **3d** Get a list of all the columns in the dataframe

# %%
df.info()
##Your code here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17401 entries, 0 to 17400
# Data columns (total 13 columns):
# Subject                          17074 non-null object
# From                             17397 non-null object
# To                               16181 non-null object
# cc                               5252 non-null object
# bcc                              11 non-null object
# Folder                           17397 non-null object
# Origin                           17397 non-null object
# FileName                         14979 non-null object
# content                          17369 non-null object
# user                             17401 non-null object
# labeled                          17401 non-null bool
# dollarValueMentionedinMessage    2244 non-null float64
# messageLength                    17401 non-null int64
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 1.6+ MB

# %% [markdown]
# **3e** Get counts of the number of times each email sender appears in the 'From' column of the dataframe

# %%
df['From'].value_counts()
##Your code here
# Out:
# Davis, Pete </O=ENRON/OU=NA/CN=RECIPIENTS/CN=PDAVIS1>                                                                                                     1392
# Williams III, Bill </O=ENRON/OU=NA/CN=RECIPIENTS/CN=BWILLIA5>                                                                                              583
# Liz M Taylor                                                                                                                                               563
# White, Stacey W. </O=ENRON/OU=NA/CN=RECIPIENTS/CN=SWHITE>                                                                                                  482
# Greg Whalley                                                                                                                                               411
# Zipper, Andy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=AZIPPER>                                                                                                     372
# Stacey W White                                                                                                                                             356
# Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/CN=JZUFFER>                                                                                                   339
# Enron Announcements                                                                                                                                        332
# Whitt, Mark </O=ENRON/OU=NA/CN=RECIPIENTS/CN=MWHITT>                                                                                                       332
# Outlook Migration Team <Outlook Migration Team/Corp/Enron@ECT>                                                                                             291
# Symes, Kate </O=ENRON/OU=NA/CN=RECIPIENTS/CN=KSYMES>                                                                                                       156
# Evans, Casey </O=ENRON/OU=NA/CN=RECIPIENTS/CN=CEVANS>                                                                                                      138
# "Cherry, Beth" <Beth.Cherry@enform.com>                                                                                                                    133
# Y'Barbo, Paul </O=ENRON/OU=NA/CN=RECIPIENTS/CN=PYBARBO>                                                                                                    122
# Postlethwaite, John </O=ENRON/OU=NA/CN=RECIPIENTS/CN=JPOSTLE>                                                                                               99
# Zionette Vincent                                                                                                                                            98
# Wolfe, Jason </O=ENRON/OU=NA/CN=RECIPIENTS/CN=JWOLFE>                                                                                                       98
# Paul Y'Barbo                                                                                                                                                98
# Chris Abel                                                                                                                                                  90
# "Cherry, Beth" <Beth.Cherry@enform.com>@ENRON <IMCEANOTES-+22Cherry+2C+20Beth+22+20+3CBeth+2ECherry+40enform+2Ecom+3E+40ENRON@ENRON.com>                    90
# Dahlke, Andrea </O=ENRON/OU=NA/CN=RECIPIENTS/CN=ADAHLKE>                                                                                                    84
# Alport, Kysa </O=ENRON/OU=NA/CN=RECIPIENTS/CN=KALPORT>                                                                                                      83
# Rodriguez, Grace </O=ENRON/OU=NA/CN=RECIPIENTS/CN=GRODRIQ>                                                                                                  82
# Chang, Fran </O=ENRON/OU=NA/CN=RECIPIENTS/CN=FCHANG>                                                                                                        78
# Todd Peterson                                                                                                                                               74
# Taylor, Liz M. </O=ENRON/OU=NA/CN=RECIPIENTS/CN=LTAYLOR>                                                                                                    71
# Jeffrey Snyder                                                                                                                                              69
# Rhonda L Denton                                                                                                                                             69
# Whalley, Greg </O=ENRON/OU=NA/CN=RECIPIENTS/CN=GWHALLE>                                                                                                     68
#                                                                                                                                                           ...
# Victor Vega <Victor Vega/ENRON_DEVELOPMENT@ENRON_DEVELOPMENT>                                                                                                1
# "Travis Cherry" <travis.cherry@enform.com>@ENRON                                                                                                             1
# "P.Willis" <we541be@ssel.toshiba.co.jp>@ENRON                                                                                                                1
# Travelocity Member Services <6.1132.6c-af5SsclXjfAGjsRR.1@mail3.travelocity.com>@ENRON                                                                       1
# Nieten, Joseph </O=ENRON/OU=NA/CN=RECIPIENTS/CN=JNIETEN>                                                                                                     1
# Darrin Donegan <Darrin Donegan/ENRON_DEVELOPMENT@ENRON_DEVELOPMENT>                                                                                          1
# petroleumargus.com <R-8-56294-3745823-2-7248-US2-A156BB74@xmr3.com>                                                                                          1
# Thresa A Allen <Thresa A Allen/HOU/ECT@ECT>                                                                                                                  1
# Rosanna Migliaccio <Rosanna.Migliaccio@robertwalters.com>                                                                                                    1
# 4uc5@msn.com@ENRON                                                                                                                                           1
# "jcrew.com" <service@click.jcrew.com>@ENRON <IMCEANOTES-+22jcrew+2Ecom+22+20+3Cservice+40click+2Ejcrew+2Ecom+3E+40ENRON@ENRON.com>                           1
# Michael Zotter <zottermj@hotmail.com>                                                                                                                        1
# ur9qncobbv@hotmail.com@ENRON                                                                                                                                 1
# "Paul W." <oxxsv@zxmail.com>@ENRON                                                                                                                           1
# Aurther Newton <aplldd@yahoo.com>                                                                                                                            1
# Miller, Tim <millertr@bp.com>                                                                                                                                1
# vAlgcawson@yahoo.com@ENRON <IMCEANOTES-vAlgcawson+40yahoo+2Ecom+40ENRON@ENRON.com>                                                                           1
# RealPlayer <news@real-net.net>@ENRON <IMCEANOTES-RealPlayer+20+3Cnews+40real-net+2Enet+3E+40ENRON@ENRON.com>                                                 1
# Sandbox Special Announcement <member@sandbox.com>@ENRON <IMCEANOTES-Sandbox+20Special+20Announcement+20+3Cmember+40sandbox+2Ecom+3E+40ENRON@ENRON.com>       1
# Smith, Rick </O=ENRON/OU=NA/CN=RECIPIENTS/CN=NOTESADDR/CN=4F0FF757-A90607B4-86256744-56118F>                                                                 1
# howardfamily@hotmail.com@ENRON <IMCEANOTES-howardfamily+40hotmail+2Ecom+40ENRON@ENRON.com>                                                                   1
# jvxwj@eon.dk@ENRON                                                                                                                                           1
# ETS Omaha Solution Center </O=ENRON/OU=NA/CN=RECIPIENTS/CN=MBX_ETSSOLNCTR>                                                                                   1
# philblunt2@isitpat.com@ENRON <IMCEANOTES-philblunt2+40isitpat+2Ecom+40ENRON@ENRON.com>                                                                       1
# Van Horn, Mike </O=ENRON/OU=NA/CN=RECIPIENTS/CN=MVANHOR>                                                                                                     1
# LiteBytz@enron.com                                                                                                                                           1
# "Karyn Elder" <karyn@dewittec.net>@ENRON                                                                                                                     1
# Lambie, Chris </O=ENRON/OU=NA/CN=RECIPIENTS/CN=CLAMBIE>                                                                                                      1
# Smith L Day <Smith L Day/HOU/ECT@ECT>                                                                                                                        1
# Gordon, D'Ann </O=ENRON/OU=NA/CN=RECIPIENTS/CN=DGORDON>                                                                                                      1
# Name: From, Length: 2195, dtype: int64

# %% [markdown]
# (We'll learn how to clean this up in module 10)

# %% [markdown]
# ### Part 4 - Selecting rows and columns

# %% [markdown]
# **4a** Select just the 'From' column of the data frame

# %%
fromColumn=df['From']
fromColumn.head()
# Out:
# 0    Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1    Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2    Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3    Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4    Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# Name: From, dtype: object

# %% [markdown]
# **4b** Select the 4th row of the dataframe

# %%
fourthRow=df.iloc[0]

# %% [markdown]
# **4c** Select only the item in the from column from the fourth row of the data frame

# %%
fourthFrom=df['From'][0]
fourthFrom
# Out:
# 'Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN=NOTESADDR/CN=CDE8DAE-A0B9AB37-862566B7-7A1609>'

# %% [markdown]
# ### If you have time

# %% [markdown]
# Select rows 5 through 7 of the dataframe

# %%
fiveThroughSeven=df.iloc[5:8]
fiveThroughSeven
# Out:
#                                              Subject  \
# 5  CPUC Proposed Decision Modifying Negative CTC ...
# 6             CPUC Decision Suspending Direct Access
# 7                                    California 7/31
#
#                                                 From  \
# 5   James D Steffes <James D Steffes/NA/Enron@ENRON>
# 6   James D Steffes <James D Steffes/NA/Enron@ENRON>
# 7  Johnston, Robert </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                                   To  \
# 5  Steven J Kean <Steven J Kean/NA/Enron@Enron>, ...
# 6  David W Delainey <David W Delainey/HOU/EES@EES...
# 7  Whalley, Greg </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
#
#                                                   cc  bcc  \
# 5                                                NaN  NaN
# 6  Harry Kingerski <Harry Kingerski/NA/Enron@Enro...  NaN
# 7  Hickerson, Gary </O=ENRON/OU=NA/CN=RECIPIENTS/...  NaN
#
#                               Folder     Origin                      FileName  \
# 5  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 6  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
# 7  \GWHALLE (Non-Privileged)\Markets  WHALLEY-G  GWHALLE (Non-Privileged).pst
#
#                                              content       user  labeled  \
# 5  In the same Decision that the CPUC is consider...  whalley-g    False
# 6  The following points highlight legal/regulator...  whalley-g    False
# 7  The train wreck known as California utility cr...  whalley-g    False
#
#    dollarValueMentionedinMessage  messageLength
# 5                            NaN           1793
# 6                            NaN           2042
# 7                            NaN           5417

# %% [markdown]
# Select the to and from columns of the dataframe with a single line of code

# %%
toAndFrom=df[['To','From']]
toAndFrom.head()
# Out:
#                                                   To  \
# 0  Kean, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...
# 1  Greg Whalley/HOU/ECT@ENRON, Lavorato, John </O...
# 2  skean@enron.com, Shapiro, Richard </O=ENRON/OU...
# 3  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 4  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
#
#                                                 From
# 0  Fulton, Donna </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1  Delainey, David </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2  Dasovich, Jeff </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 3  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...

# %% [markdown]
# Select the 4th and 5th columns of the dataframe

# %%
colsFourAndFive=df.iloc[:,4:6]
colsFourAndFive.head()
# Out:
#    bcc                             Folder
# 0  NaN  \GWHALLE (Non-Privileged)\Markets
# 1  NaN  \GWHALLE (Non-Privileged)\Markets
# 2  NaN  \GWHALLE (Non-Privileged)\Markets
# 3  NaN  \GWHALLE (Non-Privileged)\Markets
# 4  NaN  \GWHALLE (Non-Privileged)\Markets

# %% [markdown]
# Get the average (mean, median, or mode) of the dollarValueMentionedinMessage column

# %%
dollarAverage=df['dollarValueMentionedinMessage'].mean()
dollarAverage
# Out:
# 3048070.3057040996
